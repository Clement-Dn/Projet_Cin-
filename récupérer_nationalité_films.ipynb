# %%
# Importation des librairies
from webscraping.ws_fonctions import *

# %%
#Ici, j'importe les données du CNC en utilisant un API.
import requests
import pandas as pd
api_root = "https://public.opendatasoft.com/api/explore/v2.1/catalog/datasets/cnc-production-cinematographique-liste-des-films-agrees/records?limit=100"
response = requests.get(api_root)
films_cnc_brut = response.json() #je mets tout dans un dico json
print(response.content[:1000])

films_cnc = pd.json_normalize(films_cnc_brut["results"]) #Je crée un joli dataframe
films_cnc.head(10)
# Out:
# b'{"total_count": 4620, "results": [{"visa": "126853", "titre": "APRES LE SUD", "realisateur": "JAUFFRET Jean-Jacques", "producteurs": "EXPLICIT FILMS", "devis": 917686.0, "genre": "Fiction", "eof": null, "rang": "1", "asr": "avant", "payante": null, "clair": null, "nationalite": ["France"], "date": "2010", "decomposition": "France-100", "aides": ["Aide R\\u00e9gionale"]}, {"visa": "127800", "titre": "BIEN-AIMES (LES)", "realisateur": "HONORE Christophe", "producteurs": "FRANCE 2 CINEMA / WHY NOT PRODUCTIONS", "devis": 6814038.0, "genre": "Fiction", "eof": null, "rang": "3", "asr": null, "payante": null, "clair": null, "nationalite": ["France", "Grande Bretagne", "Republique Tcheque"], "date": "2010", "decomposition": "France-70 / Grande Bretagne-20 / Republique Tcheque-10", "aides": ["Sofica", "Cr\\u00e9dit D\'impot"]}, {"visa": "121558", "titre": "DE BON MATIN", "realisateur": "MOUTOUT Jean-Marc", "producteurs": "CENTRE EUROPEEN CINEMATOGRAPHIQUE RHONE ALPES / FRANCE 2 CINEMA / LES FILMS '
#      visa                     titre              realisateur  \
# 0  126853              APRES LE SUD    JAUFFRET Jean-Jacques
# 1  127800          BIEN-AIMES (LES)        HONORE Christophe
# 2  121558              DE BON MATIN        MOUTOUT Jean-Marc
# 3  123165                     ELLES     SZUMOWSKA Malgorzata
# 4  123905             MONSIEUR PAPA                MERAD Kad
# 5  124052  MOURIR ? PLUTÔT CREVER !        MERCURIO Stéphane
# 6  125681                     NOCES          BEZIAT Philippe
# 7  119386              NUIT BLANCHE          JARDIN Frédéric
# 8  108270              TABLEAU (LE)  LAGUIONIE Jean-François
# 9  120166           UNE FOLLE ENVIE         JEANJEAN Bernard
#
#                                          producteurs      devis         genre  \
# 0                                     EXPLICIT FILMS   917686.0       Fiction
# 1              FRANCE 2 CINEMA / WHY NOT PRODUCTIONS  6814038.0       Fiction
# 2  CENTRE EUROPEEN CINEMATOGRAPHIQUE RHONE ALPES ...  4047480.0       Fiction
# 3  LIBERATOR 2 / SLOT MACHINE / ZENTROPA INTERNAT...  3533856.0       Fiction
# 4  ARCADIA / BEL OMBRE FILMS / ESKWAD / M6 FILMS ...  9737805.0       Fiction
# 5  IMAGE SON KINESCOPE ET REALISATIONS AUDIOVISUE...   351344.0  Documentaire
# 6  CENTRE EUROPEEN CINEMATOGRAPHIQUE RHONE ALPES ...  1298022.0       Fiction
# 7                                     CHIC FILMS SAS  4580458.0       Fiction
# 8  BLUE SPIRIT PRODUCTIONS / FRANCE 3 CINEMA / RE...  4262731.0     Animation
# 9  LES FILMS DU KIOSQUE / SOCIETE NOUVELLE DE DIS...  5370373.0       Fiction
#
#     eof rang    asr payante clair  \
# 0  None    1  avant    None  None
# 1  None    3   None    None  None
# 2  None    3   None    None  None
# 3  None    3   None    None  None
# 4  None    1   None    None    W9
# 5  None    2  après    None  None
# 6  None    2  avant    None  None
# 7  None    3   None    None  None
# 8  None    3   None    None  None
# 9  None    3   None    None  None
#
#                                      nationalite  date  \
# 0                                       [France]  2010
# 1  [France, Grande Bretagne, Republique Tcheque]  2010
# 2                             [France, Belgique]  2010
# 3                   [Pologne, Allemagne, France]  2010
# 4                                       [France]  2010
# 5                                       [France]  2010
# 6                               [France, Suisse]  2010
# 7                 [France, Belgique, Luxembourg]  2010
# 8                             [France, Belgique]  2010
# 9                                       [France]  2010
#
#                                        decomposition  \
# 0                                         France-100
# 1  France-70 / Grande Bretagne-20 / Republique Tc...
# 2                            France-90 / Belgique-10
# 3              Pologne-44 / Allemagne-29 / France-25
# 4                                         France-100
# 5                                         France-100
# 6                              France-90 / Suisse-10
# 7            France-41 / Belgique-32 / Luxembourg-26
# 8                            France-80 / Belgique-20
# 9                                         France-100
#
#                                       aides
# 0                          [Aide Régionale]
# 1                  [Sofica, Crédit D'impot]
# 2  [Sofica, Crédit D'impot, Aide Régionale]
# 3                                  [Sofica]
# 4                  [Sofica, Crédit D'impot]
# 5                          [Aide Régionale]
# 6                  [Sofica, Crédit D'impot]
# 7                                      None
# 8          [Crédit D'impot, Aide Régionale]
# 9                  [Sofica, Crédit D'impot]

# %%
#Je récupère la base de film allociné
get_comparaison_notes(2020, 2)
# Out:
#                  date     durée                 auteur spectateur presse  \
# 0     21 octobre 2020  1h 27min        Albert Dupontel        3,9    3,7
# 1        18 août 2021  1h 44min         Cédric Jimenez        4,2    3,5
# 2      5 février 2020  1h 53min            Guy Ritchie        4,1    3,5
# 3    8 septembre 2021  2h 10min            Yann Gozlan        4,2    3,8
# 4   15 septembre 2021  1h 38min        Laurent Lafitte        2,7    3,1
# 5     14 juillet 2021  2h 10min        Kevin Macdonald        4,2    3,8
# 6      5 février 2020  1h 49min              Cathy Yan        2,7    2,5
# 7        16 mars 2021  1h 45min        Robert Zemeckis        2,5    3,1
# 8         9 mars 2022  1h 33min        Eric Fraticelli        2,5    1,8
# 9        10 août 2022  1h 40min       Frédéric Quiring        2,0    1,5
# 10     7 octobre 2020  1h 29min          Noémie Saglio        2,6    3,1
# 11        2 mars 2022  1h 40min        Alain Guiraudie        3,1    3,4
# 12  16 septembre 2020  2h 02min        Emmanuel Mouret        3,6    4,3
# 13    19 février 2020  1h 40min          Chris Sanders        3,7    3,2
# 14       23 mars 2022  1h 32min        Manuel Schapira        3,0    2,5
# 15     8 juillet 2020  1h 30min       Jean-Pascal Zadi        2,8    3,8
# 16    13 octobre 2021  1h 45min            Rana Kazkaz        3,0    3,2
# 17    29 janvier 2020  2h 17min  Destin Daniel Cretton        4,1    3,0
# 18       26 août 2020  2h 30min      Christopher Nolan        3,6    3,6
# 19     5 février 2020  1h 42min         Stephen Gaghan        2,9    2,2
# 20    1 décembre 2021  2h 32min      Mohammad Rasoulof        4,1    4,1
# 21    19 février 2020  2h 09min         Clint Eastwood        4,1    4,0
# 22       26 juin 2022  2h 17min            David Prior        2,7    4,0
# 23        26 mai 2021  1h 38min         Florian Zeller        4,3    3,9
# 24    20 octobre 2021  1h 43min             Tomm Moore        4,3    4,2
#
#                genre1           genre2       genre3
# 0             Comédie
# 1            Policier         Thriller
# 2              Action         Policier
# 3               Drame         Thriller
# 4             Comédie
# 5              Biopic            Drame     Thriller
# 6              Action         Aventure
# 7             Comédie          Famille  Fantastique
# 8             Comédie
# 9             Comédie
# 10            Comédie          Famille
# 11            Comédie
# 12            Comédie            Drame      Romance
# 13           Aventure            Drame      Famille
# 14              Drame
# 15            Comédie
# 16              Drame         Thriller
# 17             Biopic            Drame
# 18             Action  Science Fiction
# 19            Comédie          Famille
# 20              Drame
# 21              Drame
# 22  Epouvante-horreur         Thriller
# 23              Drame
# 24           Aventure        Animation      Famille
